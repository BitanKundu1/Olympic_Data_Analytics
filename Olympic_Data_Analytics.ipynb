# %% [markdown]
# <a href="https://colab.research.google.com/github/BitanKundu1/Olympic_Data_Analytics/blob/main/Olympic_Data_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print(os.listdir())
# Out:
# ['.config', 'drive', 'sample_data']

# %%
df = pd.read_csv('/content/drive/MyDrive/olympics_dataset.csv')

# %%
df
# Out:
#         player_id                   Name Sex               Team  NOC  Year  \
# 0               0              A Dijiang   M              China  CHN  1992
# 1               1               A Lamusi   M              China  CHN  2012
# 2               2            Gunnar Aaby   M            Denmark  DEN  1920
# 3               3            Edgar Aabye   M     Denmark/Sweden  DEN  1900
# 4              26  Cornelia (-strannood)   F        Netherlands  NED  1932
# ...           ...                    ...  ..                ...  ...   ...
# 252560    4986655             Sefora Ada   F  Equatorial Guinea  GEQ  2024
# 252561    9460001        Emanuela Liuzzi   F              Italy  ITA  2024
# 252562    1972077           Isayah Boers   M        Netherlands  NED  2024
# 252563    1899865            Kevin Staut   M             France  FRA  2024
# 252564    1924402        Charlie Carvell   M      Great Britain  GBR  2024
#
# ...

# %%
df.isnull().sum()   # check for null values
# Out:
# player_id    0
# Name         0
# Sex          0
# Team         0
# NOC          0
# Year         0
# Season       0
# City         0
# Sport        0
# Event        0
# Medal        0
# dtype: int64

# %%
unique_df = df.drop_duplicates()        # remove unique rows

# %%
unique_df
# Out:
#         player_id                   Name Sex               Team  NOC  Year  \
# 0               0              A Dijiang   M              China  CHN  1992
# 1               1               A Lamusi   M              China  CHN  2012
# 2               2            Gunnar Aaby   M            Denmark  DEN  1920
# 3               3            Edgar Aabye   M     Denmark/Sweden  DEN  1900
# 4              26  Cornelia (-strannood)   F        Netherlands  NED  1932
# ...           ...                    ...  ..                ...  ...   ...
# 252560    4986655             Sefora Ada   F  Equatorial Guinea  GEQ  2024
# 252561    9460001        Emanuela Liuzzi   F              Italy  ITA  2024
# 252562    1972077           Isayah Boers   M        Netherlands  NED  2024
# 252563    1899865            Kevin Staut   M             France  FRA  2024
# 252564    1924402        Charlie Carvell   M      Great Britain  GBR  2024
#
# ...

# %%
print(unique_df.shape)    # print number of unique rows and columns
# Out:
# (252565, 11)

# %%
df2 = unique_df.drop(['player_id','NOC','Season'], axis=1)

# %%
df2
# Out:
#                          Name Sex               Team  Year         City  \
# 0                   A Dijiang   M              China  1992    Barcelona
# 1                    A Lamusi   M              China  2012       London
# 2                 Gunnar Aaby   M            Denmark  1920    Antwerpen
# 3                 Edgar Aabye   M     Denmark/Sweden  1900        Paris
# 4       Cornelia (-strannood)   F        Netherlands  1932  Los Angeles
# ...                       ...  ..                ...   ...          ...
# 252560             Sefora Ada   F  Equatorial Guinea  2024        Paris
# 252561        Emanuela Liuzzi   F              Italy  2024        Paris
# 252562           Isayah Boers   M        Netherlands  2024        Paris
# 252563            Kevin Staut   M             France  2024        Paris
# 252564        Charlie Carvell   M      Great Britain  2024        Paris
#
#              Sport                         Event     Medal
# ...

# %%
print(df2.shape)
# Out:
# (252565, 8)

# %%
sex_counts = df2['Sex'].value_counts()

# Calculate participation rate (assuming total participation is the number of rows in df2)
participation_rate = sex_counts / len(df2) * 100

# Plotting the data
plt.figure(figsize=(8, 6))
sns.barplot(x=participation_rate.index, y=participation_rate.values, palette='Blues_d')

# Adding titles and labels
plt.title('Sex vs Participation Rate', fontsize=16)
plt.xlabel('Sex', fontsize=14)
plt.ylabel('Participation Rate (%)', fontsize=14)

# Display the plot
plt.show()
# Out:
# <ipython-input-13-5033f99386a9>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=participation_rate.index, y=participation_rate.values, palette='Blues_d')

# %%
sex_counts = df2['Sex'].value_counts()

# Calculate participation rate (assuming total participation is the number of rows in df2)
participation_rate = sex_counts / len(df2) * 100

# Print participation rate for each sex
for sex, rate in participation_rate.items():
    print(f"{sex}: {rate:.2f}%")
# Out:
# M: 70.69%
# F: 29.31%

# %%
year_counts = df2['Year'].value_counts()

# Calculate participation rate (assuming total participation is the number of rows in df2)
participation_rate = year_counts / len(df2) * 100

# Plotting the data
plt.figure(figsize=(14, 6))
sns.barplot(x=participation_rate.index, y=participation_rate.values, palette='Blues_d')
plt.xticks(rotation=90)

# Adding titles and labels
plt.title('Year vs Participation Rate', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Participation Rate (%)', fontsize=14)

# Display the plot
plt.show()
# Out:
# <ipython-input-15-c3717b0dee7d>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=participation_rate.index, y=participation_rate.values, palette='Blues_d')

# %%
year_counts = df2['Year'].value_counts()

# Calculate participation rate (assuming total participation is the number of rows in df2)
participation_rate = year_counts / len(df2) * 100

# Print participation rate for each year
for year, rate in participation_rate.items():
    print(f"{year}: {rate:.2f}%")
# Out:
# 2020: 5.99%
# 2024: 5.90%
# 2000: 5.47%
# 1996: 5.46%
# 2016: 5.42%
# 2008: 5.39%
# 2004: 5.32%
# 1992: 5.14%
# 2012: 5.12%
# 1988: 4.77%
# 1972: 4.08%
# 1984: 3.74%
# 1976: 3.42%
# 1968: 3.40%
# 1952: 3.27%
# 1960: 3.21%
# 1964: 3.05%
# 1980: 2.85%
# 1936: 2.58%
# 1948: 2.54%
# 1924: 2.07%
# 1956: 2.03%
# 1928: 1.98%
# 1920: 1.70%
# 1912: 1.60%
# 1908: 1.23%
# 1932: 1.18%
# 1900: 0.77%
# 1906: 0.69%
# 1904: 0.52%
# 1896: 0.15%

# %%
no_year = df2['Year'].nunique()
print(no_year)
# Out:
# 31

# %%
sport_counts = df2['Sport'].value_counts()

# Calculate participation rate (assuming total participation is the number of rows in df2)
participation_rate = sport_counts / len(df2) * 100

# Plotting the data
plt.figure(figsize=(14, 6))
sns.barplot(x=participation_rate.index, y=participation_rate.values, palette='Blues_d')
plt.xticks(rotation=90)

# Adding titles and labels
plt.title('Sport vs Participation Rate', fontsize=16)
plt.xlabel('Sport', fontsize=14)
plt.ylabel('Participation Rate (%)', fontsize=14)

# Display the plot
plt.show()
# Out:
# <ipython-input-18-1a7b515b91ad>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=participation_rate.index, y=participation_rate.values, palette='Blues_d')

# %%
most_frequent_sport = df2['Sport'].mode()[0]
print("Most frequent sport:", most_frequent_sport)
# Out:
# Most frequent sport: Athletics

# %%
sport_counts = df2['Sport'].value_counts().head(10)

# Calculate participation rate (assuming total participation is the number of rows in df2)
participation_rate = sport_counts / len(df2) * 100

# Print participation rate for top 10 sports
for sport, rate in participation_rate.items():
  print(f"{sport}: {rate:.2f}%")
# Out:
# Athletics: 17.14%
# Gymnastics: 10.57%
# Swimming: 10.46%
# Shooting: 4.98%
# Rowing: 4.60%
# Fencing: 4.58%
# Cycling: 4.30%
# Football: 3.13%
# Wrestling: 3.06%
# Sailing: 2.88%

# %%
no_sport = df2['Sport'].nunique()
print(no_sport)
# Out:
# 76

# %%
city_counts = df2.groupby('City')['Year'].nunique().reset_index(name='Total Years')

# Sort the values for a better visual presentation
city_counts_sorted = city_counts.sort_values(by='Total Years', ascending=False)

print("Total number of years each city hosted the events:")
for index, row in city_counts_sorted.iterrows():
    print(f"{row['City']} hosted the events {row['Total Years']} times.")

# Plotting
plt.figure(figsize=(10, 6))
plt.barh(city_counts_sorted['City'], city_counts_sorted['Total Years'], color='skyblue')

plt.title('Total Number of Years Each City Hosted the Events')
plt.xlabel('Number of Years')
plt.ylabel('City')
plt.tight_layout()
plt.show()
# Out:
# Total number of years each city hosted the events:
# Athina hosted the events 3 times.
# London hosted the events 3 times.
# Paris hosted the events 3 times.
# Tokyo hosted the events 2 times.
# Stockholm hosted the events 2 times.
# Los Angeles hosted the events 2 times.
# Moskva hosted the events 1 times.
# Sydney hosted the events 1 times.
# St. Louis hosted the events 1 times.
# Seoul hosted the events 1 times.
# Roma hosted the events 1 times.
# Rio de Janeiro hosted the events 1 times.
# Munich hosted the events 1 times.
# Amsterdam hosted the events 1 times.
# Montreal hosted the events 1 times.
# Antwerpen hosted the events 1 times.
# Melbourne hosted the events 1 times.
# Helsinki hosted the events 1 times.
# Berlin hosted the events 1 times.
# Beijing hosted the events 1 times.
# Barcelona hosted the events 1 times.
# Atlanta hosted the events 1 times.
# Mexico City hosted the events 1 times.

# %%
no_city = df2['City'].nunique()
print(no_city)
# Out:
# 23

# %%
team_counts = df2['Team'].value_counts().head(10)

# Calculate participation rate (assuming total participation is the number of rows in df2)
participation_rate = team_counts / len(df2) * 100

# Plotting the data
plt.figure(figsize=(14, 6))
sns.barplot(x=participation_rate.index, y=participation_rate.values, palette='Blues_d')
plt.xticks(rotation=90)

# Adding titles and labels
plt.title('Top 10 Team vs Participation Rate', fontsize=16)
plt.xlabel('Team', fontsize=14)
plt.ylabel('Participation Rate (%)', fontsize=14)

# Display the plot
plt.show()
# Out:
# <ipython-input-24-8c65bfa037d4>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=participation_rate.index, y=participation_rate.values, palette='Blues_d')

# %%
team_counts = df2['Team'].value_counts().tail(10)  # Get the last 10 teams

# Calculate participation rate
participation_rate = team_counts / len(df2) * 100

# Plotting
plt.figure(figsize=(12, 6))
sns.barplot(x=participation_rate.index, y=participation_rate.values, palette='viridis')
plt.title('Participation Rate for the Last 10 Teams')
plt.xlabel('Team')
plt.ylabel('Participation Rate (%)')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-25-923a9673a56b>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=participation_rate.index, y=participation_rate.values, palette='viridis')

# %%
team_counts = df2['Team'].value_counts().head(10)

# Calculate participation rate (assuming total participation is the number of rows in df2)
participation_rate = team_counts / len(df2) * 100

# Print participation rate for top 10 teams
for team, rate in participation_rate.items():
  print(f"{team}: {rate:.2f}%")
# Out:
# United States: 6.43%
# Great Britain: 4.51%
# France: 4.50%
# Italy: 3.64%
# Germany: 3.41%
# Australia: 3.27%
# Canada: 3.06%
# Japan: 3.02%
# Hungary: 2.61%
# Sweden: 2.44%

# %%
no_team = df2['Team'].nunique()
print(no_team)
# Out:
# 1193

# %%
event_counts = df2['Event'].value_counts().head(10)

# Calculate participation rate (assuming total participation is the number of rows in df2)
participation_rate = event_counts / len(df2) * 100

# Plotting the data
plt.figure(figsize=(14, 6))
sns.barplot(x=participation_rate.index, y=participation_rate.values, palette='Blues_d')
plt.xticks(rotation=90)

# Adding titles and labels
plt.title('Top 10 Event vs Participation Rate', fontsize=16)
plt.xlabel('Event', fontsize=14)
plt.ylabel('Participation Rate (%)', fontsize=14)

# Display the plot
plt.show()
# Out:
# <ipython-input-28-10fcd3c52847>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=participation_rate.index, y=participation_rate.values, palette='Blues_d')

# %%
event_counts = df2['Event'].value_counts().tail(10)  # Get the last 10 events

# Calculate participation rate
participation_rate = event_counts / len(df2) * 100

# Plotting
plt.figure(figsize=(12, 6))
sns.barplot(x=participation_rate.index, y=participation_rate.values, palette='viridis')
plt.title('Participation Rate for the Last 10 Events')
plt.xlabel('Event')
plt.ylabel('Participation Rate (%)')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-29-17d85715617f>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=participation_rate.index, y=participation_rate.values, palette='viridis')

# %%
event_counts = df2['Event'].value_counts().head(10)

# Calculate participation rate (assuming total participation is the number of rows in df2)
participation_rate = event_counts / len(df2) * 100

# Print participation rate for top 10 events
for event, rate in participation_rate.items():
    print(f"{event}: {rate:.2f}%")
# Out:
# Football Men's Football: 2.27%
# Hockey Men's Hockey: 1.57%
# Water Polo Men's Water Polo: 1.33%
# Basketball Men's Basketball: 1.30%
# Cycling Men's Road Race, Individual: 1.17%
# Gymnastics Men's Individual All-Around: 0.99%
# Rowing Men's Coxed Eights: 0.96%
# Gymnastics Men's Team All-Around: 0.95%
# Handball Men's Handball: 0.90%
# Athletics Men's Marathon: 0.83%

# %%
no_event = df2['Event'].nunique()
print(no_event)
# Out:
# 1041

# %%
medals_by_year = df2.groupby('Year')['Medal'].count().reset_index()

# Plot
plt.figure(figsize=(10, 6))
sns.lineplot(x='Year', y='Medal', data=medals_by_year, marker='o')
plt.title('Medals by Year')
plt.xlabel('Year')
plt.ylabel('Number of Medals')
plt.show()

# %%
medals_by_year = df2.groupby(['Year', 'Medal']).size().unstack(fill_value=0).reset_index()


medals_by_year.columns = ['Year', 'Bronze', 'Gold', 'Silver', 'No Medal']


for index, row in medals_by_year.iterrows():
   print(f"Year: {row['Year']}, Gold: {row['Gold']}, Silver: {row['Silver']}, Bronze: {row['Bronze']}")
# Out:
# Year: 1896, Gold: 62, Silver: 237, Bronze: 38
# Year: 1900, Gold: 201, Silver: 1332, Bronze: 175
# Year: 1904, Gold: 173, Silver: 815, Bronze: 150
# Year: 1906, Gold: 157, Silver: 1275, Bronze: 145
# Year: 1908, Gold: 294, Silver: 2270, Bronze: 256
# Year: 1912, Gold: 326, Silver: 3099, Bronze: 300
# Year: 1920, Gold: 493, Silver: 2984, Bronze: 367
# Year: 1924, Gold: 277, Silver: 4401, Bronze: 274
# Year: 1928, Gold: 245, Silver: 4258, Bronze: 250
# Year: 1932, Gold: 229, Silver: 2322, Bronze: 204
# Year: 1936, Gold: 312, Silver: 5589, Bronze: 295
# Year: 1948, Gold: 289, Silver: 5553, Bronze: 279
# Year: 1952, Gold: 306, Silver: 7373, Bronze: 300
# Year: 1956, Gold: 302, Silver: 4234, Bronze: 298
# Year: 1960, Gold: 309, Silver: 7208, Bronze: 308
# Year: 1964, Gold: 347, Silver: 6673, Bronze: 343
# Year: 1968, Gold: 359, Silver: 7531, Bronze: 358
# Year: 1972, Gold: 404, Silver: 9089, Bronze: 419
# Year: 1976, Gold: 438, Silver: 7321, Bronze: 448
# ...

# %%
team_total_medals = df2.groupby('Team')['Medal'].count().reset_index()


total_medals = df2['Medal'].count()


team_total_medals['Winning Rate'] = team_total_medals['Medal'] / total_medals


top_teams_by_win_rate = team_total_medals.sort_values(by='Winning Rate', ascending=False).head(10)


print(top_teams_by_win_rate)

# Plot
plt.figure(figsize=(12, 6))
sns.barplot(x='Winning Rate', y='Team', data=top_teams_by_win_rate, palette='viridis')
plt.title('Top 10 Teams by Winning Rate')
plt.xlabel('Winning Rate')
plt.ylabel('Team')
plt.show()
# Out:
#                Team  Medal  Winning Rate
# 1105  United States  16236      0.064284
# 425   Great Britain  11390      0.045097
# 374          France  11360      0.044979
# 520           Italy   9185      0.036367
# 411         Germany   8622      0.034138
# 66        Australia   8263      0.032716
# 177          Canada   7736      0.030630
# 525           Japan   7618      0.030163
# 491         Hungary   6581      0.026057
# 1016         Sweden   6167      0.024417
# <ipython-input-34-03a3751766fd>:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Winning Rate', y='Team', data=top_teams_by_win_rate, palette='viridis')

# %%
# Assuming the user meant to use a DataFrame named df2 with the column 'Team'
team_medal_count = df2.groupby(['Team', 'Medal']).size().unstack(fill_value=0).reset_index()

# Keep only Gold, Silver, and Bronze medals
team_medal_count = team_medal_count[['Team', 'Gold', 'Silver', 'Bronze']]

# Sort by Gold and Silver medals (descending)
top_teams = team_medal_count.sort_values(by=['Gold', 'Silver'], ascending=False).head(10)

print("team_medal_count")
print(team_medal_count)

# Plot
top_teams.plot(x='Team', kind='bar', stacked=True, figsize=(12, 6), color=['#FFD700', '#C0C0C0', '#CD7F32'])  # Gold, Silver, Bronze
plt.title('Top 10 Teams by Medal Count (Gold, Silver, Bronze)')
plt.xlabel('Team')
plt.ylabel('Medal Count')
plt.legend(title='Medal Type')
plt.show()
# Out:
# team_medal_count
# Medal                   Team  Gold  Silver  Bronze
# 0                30. Februar     0       0       0
# 1      A North American Team     0       0       4
# 2                        AIN     1       4       1
# 3                  Acipactli     0       0       0
# 4                    Acturus     0       0       0
# ...                      ...   ...     ...     ...
# 1188                  Zambia     0       1       2
# 1189                 Zefyros     0       0       0
# 1190                Zimbabwe    17       4       1
# 1191                     Zut     0       3       0
# 1192                    rn-2     0       0       0
#
# [1193 rows x 4 columns]

# %%
sex_medal_count = df2.groupby(['Sex', 'Medal']).size().unstack(fill_value=0).reset_index()

# Keep only Gold, Silver, and Bronze medals
sex_medal_count = sex_medal_count[['Sex', 'Gold', 'Silver', 'Bronze']]

# Sort by Gold and Silver medals (descending)
top_sex = sex_medal_count.sort_values(by=['Gold', 'Silver'], ascending=False).head(10)

print("sex_medal_count")
print(sex_medal_count)


# Plot
top_sex.plot(x='Sex', kind='bar', stacked=True, figsize=(10, 6), color=['#FFD700', '#C0C0C0', '#CD7F32'])  # Bronze, Gold, Silver colors
plt.title('Medal Count by Gender')
plt.xlabel('Sex')
plt.ylabel('Medal Count')
plt.legend(title='Medal Type')
plt.show()
# Out:
# sex_medal_count
# Medal Sex  Gold  Silver  Bronze
# 0       F  3914    3891    3992
# 1       M  9088    8855    9078

# %%
city_medal_count = df2.groupby(['City', 'Medal']).size().unstack(fill_value=0).reset_index()

# Keep only City, Gold, Silver, and Bronze medals
city_medal_count = city_medal_count[['City', 'Gold', 'Silver', 'Bronze']]  # Correct column selection

# Sort by Gold and Silver medals (descending)
top_cities = city_medal_count.sort_values(by=['Gold', 'Silver'], ascending=False).head(10)

print("City Medal Count:")
print(city_medal_count)

# Plot
top_cities.plot(x='City', kind='bar', stacked=True, figsize=(12, 6), color=['#FFD700', '#C0C0C0', '#CD7F32'])  # Gold, Silver, Bronze
plt.title('Top 10 Cities by Medal Count')
plt.xlabel('City')
plt.ylabel('Medal Count')
plt.legend(title='Medal Type')
plt.show()
# Out:
# City Medal Count:
# Medal            City  Gold  Silver  Bronze
# 0           Amsterdam   245     239     250
# 1           Antwerpen   493     448     367
# 2              Athina   883     859     860
# 3             Atlanta   608     605     629
# 4           Barcelona   559     549     604
# 5             Beijing   671     667     710
# 6              Berlin   312     310     295
# 7            Helsinki   306     291     300
# 8              London  1215    1195    1214
# 9         Los Angeles   726     691     706
# 10          Melbourne   290     281     286
# 11        Mexico City   359     340     358
# 12           Montreal   438     434     448
# 13             Moskva   457     458     469
# 14             Munich   404     392     419
# 15              Paris  1221    1253    1243
# 16     Rio de Janeiro   665     655     703
# 17               Roma   309     294     308
# 18              Seoul   520     513     549
# 19          St. Louis   173     163     150
# ...
